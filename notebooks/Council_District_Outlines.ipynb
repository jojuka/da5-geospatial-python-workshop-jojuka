# %%
from shapely.geometry import Point
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
data = gpd.read_file('../data/Council_District_Outlines.geojson')
print(data.crs)
data.head( )
# Out:
# epsg:4326
#     first_name                  email_address business_phone_number last_name  \
# 0  Jonathan B.    Jonathan.Hall@nashville.gov          615-432-1301      Hall
# 1      Kyonzté   Kyonzte.Toombs@nashville.gov          615-432-1302    Toombs
# 2     Jennifer  Jennifer.Gamble@nashville.gov          615-432-1303    Gamble
# 3       Robert     Robert.Swope@nashville.gov          615-432-1304     Swope
# 4         Sean      Sean.Parker@nashville.gov          615-432-1305    Parker
#
#   council_district                                           geometry
# 0                1  MULTIPOLYGON (((-86.90738 36.39052, -86.90725 ...
# 1                2  MULTIPOLYGON (((-86.75902 36.23091, -86.75909 ...
# 2                3  MULTIPOLYGON (((-86.76842 36.38358, -86.76824 ...
# 3                4  MULTIPOLYGON (((-86.74489 36.05316, -86.74491 ...
# 4                5  MULTIPOLYGON (((-86.74724 36.21041, -86.74243 ...

# %%
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   first_name             35 non-null     object
#  1   email_address          35 non-null     object
#  2   business_phone_number  35 non-null     object
#  3   last_name              35 non-null     object
#  4   council_district       35 non-null     object
#  5   geometry               35 non-null     geometry
# dtypes: geometry(1), object(5)
# memory usage: 1.8+ KB

# %%
data.geometry.to_crs('EPSG:4326')
print(data.crs)
# Out:
# epsg:4326

# %%
data.loc[0, 'geometry']

# %%
print(data.loc[0, 'geometry'])
# Out:
# MULTIPOLYGON (((-86.90738248774343 36.39051512831934, -86.90724599759135 36.39047599606477, -86.90712077830904 36.39045935427112, -86.90709288961023 36.39045681635265, -86.90709126795993 36.39045668887019, -86.90702283759474 36.39045129807835, -86.90678530821764 36.39035858378855, -86.90655049716739 36.39026584867516, -86.90653868788078 36.39026021552043, -86.90633732812569 36.39016416092638, -86.9060887028967 36.39005175055225, -86.90589755383 36.38997407006486, -86.90573403546252 36.38993573813269, -86.9056059989984 36.38991032572337, -86.90551813423791 36.38988861286117, -86.90550242243242 36.38988473020141, -86.90549671584363 36.38988081389702, -86.90540106082254 36.3898151673499, -86.90531603104739 36.38974767979737, -86.905287698764 36.38972706835072, -86.90521736238897 36.38967589911619, -86.90511074174812 36.38962175808647, -86.90491989623912 36.38957044419436, -86.90484888140314 36.38955083674644, -86.90477266052591 36.38952979170336, -86.90458961699873 36.38944765350065, -8
# ...

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
leg_kwds = {'title': 'Council Lines', 'loc': 'upper left', 
            'bbox_to_anchor': (1, 1.03), 'ncol': 2}

data.plot(column = 'council_district', figsize=(10, 10),
              edgecolor = 'black', ##polygon outline
              legend = True, legend_kwds = leg_kwds, 
              cmap = 'Set2')##color map..see link above
plt.show()

# %%
data.plot(figsize = (8, 10), color = 'lightgreen')
plt.show()
